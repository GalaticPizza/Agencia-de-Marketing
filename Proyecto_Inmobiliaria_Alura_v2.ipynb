# %% [markdown]
# <a href="https://colab.research.google.com/github/GalaticPizza/Agencia-de-Marketing/blob/main/Proyecto_Inmobiliaria_Alura_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importo las librerias para comenzar el analisis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importo el data set

# %%
df = pd.read_csv('inmuebles_bogota.csv')

# %%
df
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
df.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
df.describe() #Calculos estadisticos
# Out:
#        Habitaciones        Baños           Área
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %%
df.shape #para ver la cantidad de filas y columnas
# Out:
# (9520, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Área          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inm = df.copy()

# %%
inm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Área          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inm['Valor'].unique()
# Out:
# array(['$ 360.000.000', '$ 670.000.000', '$ 1.120.000.000', ...,
#        '$ 372.100.000', '$ 1.375.000.000', '$ 144.990.000'], dtype=object)

# %%
column = {'Baños': 'Banos', 'Área': 'Area'}
inm = inm.rename(columns = column) #renombre a las columnas del data set

# %%
inm
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
inm.describe()
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %%
inm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
# localidad --> UPZ unidades de planeamiento zonal regiones usadas en beneficios de las comunidades, esto es usado por el gobierno de colombia
# Esto seria para Bogotá Colombia #117 UPZ <-- contabilizar

# %%
inm.iloc[300] #Para informacion contenida en el indice el DataFrame
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inm.iloc[300:305] #mismo proceso que slices en este caso del 300 al 304
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inm.shape
# Out:
# (9520, 8)

# %%
inm['Valor'][300] #VALOR DE LA COLUMNA POr su posicion
inm['Valor'][300:306] #VALOR DE LA COLUMNA POr su posicion
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# 305    $ 503.000.000
# Name: Valor, dtype: object

# %%
inm['Area']
# Out:
# 0        70
# 1       170
# 2       144
# 3       154
# 4       128
#        ...
# 9515     70
# 9516    100
# 9517    383
# 9518    183
# 9519     52
# Name: Area, Length: 9520, dtype: int64

# %%
inm.columns #para ver todas las columnas del df
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inm['Barrio']
# Out:
# 0           Zona Noroccidental
# 1                     Castilla
# 2              Chico Reservado
# 3                      Usaquén
# 4                  Bella Suiza
#                  ...
# 9515                   Kennedy
# 9516    Parque Central Bavaria
# 9517                  Restrepo
# 9518                  Engativa
# 9519                   Tintala
# Name: Barrio, Length: 9520, dtype: object

# %%
inm.Area.mean()
# Out:
# 146.66470588235293

# %%
inm.describe()
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %%
inm['Area'].plot()
plt.show()

# %% [markdown]
# Outlier en Area: superficie extremedamente enorme respecto de las demas

# %%
(inm.Barrio == 'Chico Reservado') #Devuelve valores booleanos respecto a los barrios reservados
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
inmueble_chico = (inm.Barrio == 'Chico Reservado')
type(inmueble_chico)
# Out:
# pandas.core.series.Series

# %%
sum((inm.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
chico_reservado = inm[inmueble_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
# cuantos barrios hay
len(inm.Barrio.value_counts())
# Out:
# 149

# %%
inm.Area.mean()
# Out:
# 146.66470588235293

# %%
inm.Barrio.value_counts() #cantidad de inmueble por barrio
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inm.UPZ.value_counts()) #Cuantas UPX hay en todo Bogotá
# Out:
# 63

# %%
inm.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
inm_barrio = inm.Barrio.value_counts()
inm_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inm_barrio.head(10).plot.bar() #me mostrara un bar plot de los primeros 10 , los inmuebles en cada uno de los barrios en orden descendete pero los top 10
# Out:
# <Axes: >

# %%
#Desafio
dl = inm.groupby(('Barrio'))[['Area']].mean()
barrio = dl
barrio
# Out:
#                           Area
# Barrio
# Alameda              97.000000
# Alhambra            190.411765
# Andes Norte         124.857143
# Antonio Nariño      163.062500
# Barrancas            70.200000
# ...                        ...
# Villa Maria         207.153846
# Villas De Granada    86.590909
# Villemar             76.888889
# Zona Franca          54.000000
# Zona Noroccidental  135.785633
#
# [149 rows x 1 columns]

# %%
#Desafio
dl = inm.groupby(('Barrio'))[['Area']].describe()
barrio = dl
barrio
# Out:
#                      Area                                               \
#                     count        mean         std   min     25%    50%
# Barrio
# Alameda               1.0   97.000000         NaN  97.0   97.00   97.0
# Alhambra             17.0  190.411765   99.782300  50.0  112.00  164.0
# Andes Norte           7.0  124.857143   49.780949  42.0  105.00  108.0
# Antonio Nariño       48.0  163.062500  151.023798  32.0   58.75   72.0
# Barrancas            15.0   70.200000    7.022413  63.0   63.00   75.0
# ...                   ...         ...         ...   ...     ...    ...
# Villa Maria          13.0  207.153846   47.310757  51.0  222.00  222.0
# Villas De Granada    22.0   86.590909   51.346312  50.0   64.00   64.0
# Villemar             18.0   76.888889   48.502139  45.0   54.25   59.0
# Zona Franca           1.0   54.000000         NaN  54.0   54.00   54.0
# Zona Noroccidental  877.0  135.785633  223.813808  16.0   61.00   78.0
#
#
# ...

# %% [markdown]
# # Consigna del desafio

# %%
#ordeno los primeros 10
#barrio.sort_values(ascending = False).head(10).plot(kind='bar')
inm[['Barrio','Area']].groupby(['Barrio']).mean().sort_values(by=['Area'], ascending=False).head(10).plot(kind='bar', color = 'Red', ylabel = 'Area')
# Out:
# <Axes: xlabel='Barrio', ylabel='Area'>

# %%
dl.head(10).plot(kind='bar') #pequeño error la media a la media aplique aqui
# Out:
# <Axes: xlabel='Barrio'>

# %%
#desafio 2--> estadistica de los campos numericos por un groupby y un describe para los valores
estadistica_gen = inm.groupby(['Valor'])
estadistica_gen.describe()
# Out:
#                 Habitaciones                                                 \
#                        count      mean       std  min  25%  50%   75%   max
# Valor
# $ 1.000.000.000         49.0  3.734694  2.539484  1.0  3.0  3.0  4.00  15.0
# $ 1.010.000.000          2.0  2.000000  0.000000  2.0  2.0  2.0  2.00   2.0
# $ 1.014.570.000          2.0  1.000000  0.000000  1.0  1.0  1.0  1.00   1.0
# $ 1.025.000.000          1.0  3.000000       NaN  3.0  3.0  3.0  3.00   3.0
# $ 1.030.000.000          2.0  3.000000  0.000000  3.0  3.0  3.0  3.00   3.0
# ...                      ...       ...       ...  ...  ...  ...   ...   ...
# $ 990.000.000           25.0  3.000000  0.957427  1.0  3.0  3.0  3.00   5.0
# $ 995.000.000           10.0  3.300000  0.483046  3.0  3.0  3.0  3.75   4.0
# $ 996.000.000            2.0  8.000000  0.000000  8.0  8.0  8.0  8.00   8.0
# $ 998.000.000            3.0  3.333333  0.577350  3.0  3.0  3.0  3.50   4.0
# ...

# %% [markdown]
# no iterar muchas veces sobre celdas que pueden provocar lecturas erroneas.

# %% [markdown]
# # Otros calculos estadisticos

# %%
inm.Area.median()
# Out:
# 80.0

# %%
inm.Area.count()
# Out:
# 9520

# %%
inm.Area.max()
# Out:
# 166243

# %%
inm.Area.min()
# Out:
# 2

# %%
inm['Valor'][0].split()
# Out:
# ['$', '360.000.000']

# %%
inm['Valor'].str.split()
#toma la informacion del panda series para tranformarlo en un string
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
#para que no se devuelva en formato de series si no en formato de data frame
#utilizo la misma linea pero con el comando --> split(expand = True)
valor = inm['Valor'].str.split(expand = True) # Formato columna valor
inm['Moneda'] = valor[0]
inm['Precio'] = valor[1]
inm.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 6962         Casa                       Casa en venta en Suba             8
# 2560  Apartamento             Apartamento en venta en Usaquén             1
# 3377  Apartamento      Apartamento en venta en Chapinero Alto             2
# 860   Apartamento  Apartamento en venta en Zona Noroccidental             3
# 4462  Apartamento      Apartamento en venta en Barrios Unidos             3
#
#       Banos  Area              Barrio                                 UPZ  \
# 6962      6   326                Suba                                Suba
# 2560      1    37             Usaquén                             Usaquén
# 3377      3    84      Chapinero Alto  CHAPINERO: Pardo Rubio + Chapinero
# 860       3    95  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4462      4   166      Barrios Unidos                           Los Andes
#
#                 Valor Moneda         Precio
# ...

# %%
inm['Precio'] = inm['Precio'].str.replace('.','', regex = True)
inm.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio
# 0    $ 360.000.000      $   360000000
# ...

# %%
inm['Tipo'].unique()
# Out:
# array(['Apartamento', 'Casa', 'Oficina/Consultorio', 'Local', 'Bodega',
#        'Lote', 'Edificio', 'Finca'], dtype=object)

# %%
inm[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
#elimino los ceros y trato de convertirlo a flotante por medio de .astype
inm['Precio_Millones'] =  inm['Precio'].astype(float)/1000000 #la divido por 1 millon para que se pueda operar sin tantos ceros
inm
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
inm.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millones
# count   9520.000000  9520.000000    9520.000000      9520.000000
# mean       3.072479     2.447899     146.664706       602.062354
# std        2.049856     1.255314    1731.379622       704.602062
# min        1.000000     0.000000       2.000000        60.000000
# 25%        2.000000     2.000000      57.000000       250.000000
# 50%        3.000000     2.000000      80.000000       409.182500
# 75%        3.000000     3.000000     135.000000       680.000000
# max      110.000000     9.000000  166243.000000     16000.000000

# %%
#observar sin tantos ceros los datos
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inm.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millones
# count       9520.00 9520.00   9520.00          9520.00
# mean           3.07    2.45    146.66           602.06
# std            2.05    1.26   1731.38           704.60
# min            1.00    0.00      2.00            60.00
# 25%            2.00    2.00     57.00           250.00
# 50%            3.00    2.00     80.00           409.18
# 75%            3.00    3.00    135.00           680.00
# max          110.00    9.00 166243.00         16000.00

# %%
inm.loc[inm['Habitaciones'] == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millones
# 897  Usaquén  $ 480.000.000      $  480000000           480.00

# %%
inm.loc[inm['Area'] == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millones
# 8401           180.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inm, x='Precio_Millones', kde=True, hue='Tipo')
plt.title('Distribución de Valores de los inmuebles en Bogotá')
plt.xlim((50,1000))
plt.show()

# %%
inm.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millones
# count       9520.00 9520.00   9520.00          9520.00
# mean           3.07    2.45    146.66           602.06
# std            2.05    1.26   1731.38           704.60
# min            1.00    0.00      2.00            60.00
# 25%            2.00    2.00     57.00           250.00
# 50%            3.00    2.00     80.00           409.18
# 75%            3.00    3.00    135.00           680.00
# max          110.00    9.00 166243.00         16000.00

# %%
inm.groupby('Tipo')['Precio_Millones'].mean()
# Out:
# Tipo
# Apartamento            519.14
# Bodega                 908.00
# Casa                   827.05
# Edificio              3078.23
# Finca                 2410.71
# Local                 1768.49
# Lote                  1263.33
# Oficina/Consultorio    956.76
# Name: Precio_Millones, dtype: float64

# %% [markdown]
# Actividad:
#
# 1) Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información);
#
# 2) Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
#agrupo los valores de precios segun el tipo de vivienda que este en el area
precios = inm.groupby(('Tipo'))[['Precio_Millones']].mean()
precios_tipo = precios
precios
# Out:
#                      Precio_Millones
# Tipo
# Apartamento                   519.14
# Bodega                        908.00
# Casa                          827.05
# Edificio                     3078.23
# Finca                        2410.71
# Local                        1768.49
# Lote                         1263.33
# Oficina/Consultorio           956.76

# %%
prit = inm.groupby('Tipo')
prit

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inm, x='Precio_Millones', kde=True, hue='Tipo')
grafica.set_title('Distribución de Valores de los inmuebles en Bogotá')
plt.xlabel('Valor de las casas')
plt.xlim((100,1000))
plt.show()

# %%
conteo_tipos = inm['Tipo'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(conteo_tipos, labels=conteo_tipos.index, autopct='%1.1f%%', startangle=140)
plt.title('Porcentaje de Tipos de Inmuebles')
plt.axis('equal') # Para asegurarse de que el gráfico sea un círculo
plt.show()

# %%
inm.Tipo.value_counts()
# Out:
# Apartamento            7327
# Casa                   2043
# Oficina/Consultorio      60
# Local                    38
# Edificio                 22
# Bodega                   13
# Finca                    11
# Lote                      6
# Name: Tipo, dtype: int64
